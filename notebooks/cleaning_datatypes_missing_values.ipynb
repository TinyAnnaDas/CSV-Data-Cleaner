# %%
import pandas as pd
import numpy as np

# %%
people = {

    "first": ["Corey", "Jane", "John", "Chris", np.nan, None, "NA"],
    "last": ["Shafer", "Doe", "Doe", "Shafer", np.nan, np.nan, "Missing"],
    "email": ["CoreyMShafer@gmail.com", "JaneDoe@gmaio.com", "JohnDoe@gmail.com", None, np.nan,"Anonymous@gmail.com", "NA"],
    "age": ["33", "55", "63", "36", None, None, "Missing"]
}

# %%
df = pd.DataFrame(people)

# Dealing with the custom missing values

df.replace('NA', np.nan, inplace=True)
df.replace("Missing", np.nan, inplace=True)

# %%
df
# Out:
#    first    last                   email   age
# 0  Corey  Shafer  CoreyMShafer@gmail.com    33
# 1   Jane     Doe       JaneDoe@gmaio.com    55
# 2   John     Doe       JohnDoe@gmail.com    63
# 3  Chris  Shafer                    None    36
# 4    NaN     NaN                     NaN  None
# 5   None     NaN     Anonymous@gmail.com  None
# 6    NaN     NaN                     NaN   NaN

# %%
df.dropna()
# Out:
#    first    last                   email age
# 0  Corey  Shafer  CoreyMShafer@gmail.com  33
# 1   Jane     Doe       JaneDoe@gmaio.com  55
# 2   John     Doe       JohnDoe@gmail.com  63

# %%
df.dropna(axis='index', how='any')
# axis == index or columns based on you wwant to drop row or column
# how = drop rows with any missing values, since the axis is index
# all = only drop rows with all missing values
# Out:
#    first    last                   email age
# 0  Corey  Shafer  CoreyMShafer@gmail.com  33
# 1   Jane     Doe       JaneDoe@gmaio.com  55
# 2   John     Doe       JohnDoe@gmail.com  63

# %%
df.dropna(axis='index', how='all')
# Out:
#    first    last                   email   age
# 0  Corey  Shafer  CoreyMShafer@gmail.com    33
# 1   Jane     Doe       JaneDoe@gmaio.com    55
# 2   John     Doe       JohnDoe@gmail.com    63
# 3  Chris  Shafer                    None    36
# 5   None     NaN     Anonymous@gmail.com  None

# %%
df.dropna(axis='columns', how='all')
# Out:
#    first     last                   email      age
# 0  Corey   Shafer  CoreyMShafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmaio.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3  Chris   Shafer                    None       36
# 4    NaN      NaN                     NaN     None
# 5   None      NaN     Anonymous@gmail.com     None
# 6     NA  Missing                      NA  Missing

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# if what we want is - we don't care if there is no first or last names we really want the email, so if no email -> drop the row

# %%
df.dropna(axis="index", how="any", subset=['email'])
# Out:
#    first     last                   email      age
# 0  Corey   Shafer  CoreyMShafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmaio.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 5   None      NaN     Anonymous@gmail.com     None
# 6     NA  Missing                      NA  Missing

# %% [markdown]
# As long as either one of the values email or last name is there, we shouldn't drop those rows

# %%
df.dropna(axis='index', how="all", subset=['email', 'last'])
# for permanently change inplace=True
# Out:
#    first     last                   email      age
# 0  Corey   Shafer  CoreyMShafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmaio.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3  Chris   Shafer                    None       36
# 5   None      NaN     Anonymous@gmail.com     None
# 6     NA  Missing                      NA  Missing

# %% [markdown]
# Dealing with the custom missing values

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %% [markdown]
# Sometimes when we are working wiht numerical values we might have to replace our NA values with a certain fixed value.

# %%
df.fillna("MISSING")
# Out:
#      first     last                   email      age
# 0    Corey   Shafer  CoreyMShafer@gmail.com       33
# 1     Jane      Doe       JaneDoe@gmaio.com       55
# 2     John      Doe       JohnDoe@gmail.com       63
# 3    Chris   Shafer                 MISSING       36
# 4  MISSING  MISSING                 MISSING  MISSING
# 5  MISSING  MISSING     Anonymous@gmail.com  MISSING
# 6  MISSING  MISSING                 MISSING  MISSING

# %%
df.fillna(0)
# inplace=True for permanencexn;lsd;kjowh;
# Out:
#    first    last                   email age
# 0  Corey  Shafer  CoreyMShafer@gmail.com  33
# 1   Jane     Doe       JaneDoe@gmaio.com  55
# 2   John     Doe       JohnDoe@gmail.com  63
# 3  Chris  Shafer                       0  36
# 4      0       0                       0   0
# 5      0       0     Anonymous@gmail.com   0
# 6      0       0                       0   0

# %% [markdown]
# ### Casting DataTypes

# %%
df
# Out:
#    first    last                   email   age
# 0  Corey  Shafer  CoreyMShafer@gmail.com    33
# 1   Jane     Doe       JaneDoe@gmaio.com    55
# 2   John     Doe       JohnDoe@gmail.com    63
# 3  Chris  Shafer                    None    36
# 4    NaN     NaN                     NaN  None
# 5   None     NaN     Anonymous@gmail.com  None
# 6    NaN     NaN                     NaN   NaN

# %%
# if we want to find the averge age of the people, the age values are not numbers
# we can check the age type as follows
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df['age'].mean()
# if you have NaN values, you have to use float instead of int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df['age'].mean()
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(np.nan)
# Out:
# float

# %%
df["age"] = df["age"].astype(int)
# if your columnd didn't have missing values this would work fine
# you have two options here
# 1. Either convert those NaN values to something else like a 0 using fillna
# 2. Cast that column to a float instead
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df["age"] = df["age"].astype(int)
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/the_tiny_developer/panda-1/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
df["age"] = df["age"].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(46.75)

# %% [markdown]
# If you have an entire dataframe of Numbers

# %%
df.astype() # convert everything all at once.

# %%
# dealing with missing values in csv
na_vals = ['NA', "Missing"]
df = pd.read_csv("../data/survey_results_public.csv", index_col="ResponseId", na_values=na_vals) #ResponseId of the df itself is a unique value
schema_df = pd.read_csv("../data/survey_results_schema.csv", index_col="qname")

# %%
pd.set_option("display.max_columns", 85) # by default, to only 20 columns are shown even if there are more than that
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", schema_df.shape[0])
pd.set_option("display.max_rows", schema_df.shape[0])

# %% [markdown]
# Interesting problem with casting some values
# Lets say that, we want to calculate the average number of coding experience
# among all of them.

# %%
df
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 49119       I am a developer by profession  25-34 years old
# 49120       I am a developer by profession  35-44 years old
# 49121       I am a developer by profession  25-34 years old
# 49122       I am a developer by profession  25-34 years old
# 49123       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49119            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49120            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49121       Secondary school (e.g. American high school, G...
# 49122                     Associate degree (A.A., A.S., etc.)
# 49123       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49119                                                Employed
# 49120                                                Employed
# 49121                                                Employed
# 49122                                                Employed
# 49123                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 1             Caring for dependents (children, elderly, etc.)      8.0
# 2                                                         NaN      2.0
# 3                                           None of the above     10.0
# 4                                           None of the above      4.0
# 5             Caring for dependents (children, elderly, etc.)     21.0
# ...                                                       ...      ...
# 49119                                                     NaN      9.0
# 49120         Caring for dependents (children, elderly, etc.)     13.0
# 49121                                                     NaN      2.0
# 49122       None of the above;Engaged in paid work (20-29 ...     10.0
# 49123                                       None of the above     10.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49119       Yes, I am not new to coding but am learning ne...
# 49120       No, I am not new to coding and did not learn n...
# 49121       Yes, I am not new to coding but am learning ne...
# 49122       No, I am not new to coding and did not learn n...
# 49123       No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49119       Online Courses or Certification (includes all ...
# 49120                                                     NaN
# 49121       Other online resources (e.g. standard search, ...
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49119       Yes, I learned how to use AI-enabled tools req...
# 49120       Yes, I learned how to use AI-enabled tools req...
# 49121       No, I didn't spend time learning in the past year
# 49122       Yes, I learned how to use AI-enabled tools for...
# 49123       No, I learned something that was not related t...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
# ...                                                       ...        ...
# 49119       AI CodeGen tools or AI-enabled apps;Technical ...       13.0
# 49120       AI CodeGen tools or AI-enabled apps;Videos (no...       15.0
# 49121                                                     NaN        NaN
# 49122       Videos (not associated with specific online co...       14.0
# 49123                                                     NaN       15.0
#
#                           DevType                   OrgSize  \
# ResponseId
# 1               Developer, mobile        20 to 99 employees
# 2             Developer, back-end      500 to 999 employees
# 3            Developer, front-end                       NaN
# 4             Developer, back-end  10,000 or more employees
# 5             Engineering manager                       NaN
# ...                           ...                       ...
# 49119       Developer, full-stack      500 to 999 employees
# 49120       Developer, full-stack  1,000 to 4,999 employees
# 49121                         NaN                       NaN
# 49122       Developer, full-stack        20 to 99 employees
# 49123       Developer, full-stack    Less than 20 employees
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
# ...                            ...
# 49119       Individual contributor
# 49120       Individual contributor
# 49121                          NaN
# 49122       Individual contributor
# 49123       Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
# ...                                                       ...
# 49119          Hybrid (some remote, leans heavy to in-person)
# 49120          Hybrid (some remote, leans heavy to in-person)
# 49121                                                     NaN
# 49122          Hybrid (some remote, leans heavy to in-person)
# 49123       Your choice (very flexible, you can come in wh...
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
# ...                                                       ...
# 49119                                                      No
# 49120       Yes, I endorsed a tool that was open-source an...
# 49121                                                     NaN
# 49122       Yes, I influenced the purchase of a substantia...
# 49123       Yes, I influenced the purchase of a substantia...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
# ...                      ...            ...            ...            ...
# 49119       Personal Project            8.0            2.0            4.0
# 49120                    NaN            NaN            NaN            NaN
# 49121                    NaN            NaN            NaN            NaN
# 49122                   Work            5.0            6.0            3.0
# 49123       Personal Project            9.0            2.0            3.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
# ...                   ...            ...            ...            ...
# 49119                 5.0            6.0            7.0            9.0
# 49120                 NaN            NaN            NaN            NaN
# 49121                 NaN            NaN            NaN            NaN
# 49122                 8.0            1.0            9.0            7.0
# 49123                 1.0            6.0            4.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 49119                 3.0            1.0            10.0                 NaN
# 49120                 NaN            NaN             NaN                 NaN
# 49121                 NaN            NaN             NaN                 NaN
# 49122                 4.0            2.0            10.0                 NaN
# 49123                 5.0            8.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
# ...                  ...           ...           ...           ...
# 49119                8.0           2.0           6.0           3.0
# 49120                NaN           NaN           NaN           NaN
# 49121                NaN           NaN           NaN           NaN
# 49122                9.0           7.0           8.0           2.0
# 49123                8.0           1.0           7.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
# ...                  ...           ...            ...            ...
# 49119                9.0           4.0            1.0            5.0
# 49120                NaN           NaN            NaN            NaN
# 49121                NaN           NaN            NaN            NaN
# 49122                4.0           6.0            3.0            5.0
# 49123                6.0           2.0            3.0            4.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
# ...                   ...            ...                ...
# 49119                 7.0           10.0                NaN
# 49120                 NaN            NaN                NaN
# 49121                 NaN            NaN                NaN
# 49122                 1.0           10.0                NaN
# 49123                 9.0           10.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                                Fintech             3.0             9.0
# 2           Retail and Consumer Services            10.0             9.0
# 3                   Software Development             9.0            11.0
# 4           Retail and Consumer Services             1.0             5.0
# 5                   Software Development             9.0            13.0
# ...                                  ...             ...             ...
# 49119               Software Development            11.0            13.0
# 49120                                NaN             NaN             NaN
# 49121                                NaN             NaN             NaN
# 49122                      Manufacturing             8.0            14.0
# 49123               Software Development             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      5.0            10.0            12.0            11.0
# 2                     12.0             1.0             6.0             2.0
# 3                      8.0            12.0             1.0             5.0
# 4                      6.0             7.0             8.0             9.0
# 5                     14.0             8.0             6.0             5.0
# ...                    ...             ...             ...             ...
# 49119                 12.0            10.0             6.0             1.0
# 49120                  NaN             NaN             NaN             NaN
# 49121                  NaN             NaN             NaN             NaN
# 49122                 11.0            10.0             1.0             2.0
# 49123                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 1                      2.0              6.0              7.0             13.0
# 2                     11.0              4.0              7.0             13.0
# 3                      2.0              4.0              3.0             13.0
# 4                     10.0             11.0             12.0             13.0
# 5                      7.0              2.0              1.0             12.0
# ...                    ...              ...              ...              ...
# 49119                  9.0             14.0              2.0              8.0
# 49120                  NaN              NaN              NaN              NaN
# 49121                  NaN              NaN              NaN              NaN
# 49122                  5.0             13.0              7.0             12.0
# 49123                  NaN              NaN              NaN              NaN
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 1                      14.0             15.0              8.0
# 2                      14.0             15.0              5.0
# 3                      14.0             15.0             10.0
# 4                      14.0             15.0              3.0
# 5                      10.0             15.0              3.0
# ...                     ...              ...              ...
# 49119                   7.0             15.0              3.0
# 49120                   NaN              NaN              NaN
# 49121                   NaN              NaN              NaN
# 49122                   6.0             15.0              4.0
# 49123                   NaN              NaN              NaN
#
#            JobSatPoints_15_TEXT      AIThreat  \
# ResponseId
# 1                           NaN  I'm not sure
# 2                           NaN  I'm not sure
# 3                           NaN            No
# 4                           NaN            No
# 5                           NaN            No
# ...                         ...           ...
# 49119                       NaN  I'm not sure
# 49120                       NaN           NaN
# 49121                       NaN           NaN
# 49122                       NaN            No
# 49123                       NaN            No
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 1           I have neither consider or transitioned into a...            7.0
# 2           I have transitioned into a new career and/or i...            6.0
# 3           I have transitioned into a new career and/or i...            3.0
# 4           I have neither consider or transitioned into a...            NaN
# 5           I have neither consider or transitioned into a...            4.0
# ...                                                       ...            ...
# 49119       I have somewhat considered changing my career ...            NaN
# 49120                                                     NaN            NaN
# 49121                                                     NaN            NaN
# 49122       I have somewhat considered changing my career ...            8.0
# 49123       I have somewhat considered changing my career ...            NaN
#
#             ToolCountPersonal      Country                  Currency  \
# ResponseId
# 1                         3.0      Ukraine         EUR European Euro
# 2                         5.0  Netherlands         EUR European Euro
# 3                         3.0      Ukraine     UAH Ukrainian hryvnia
# 4                         NaN      Ukraine         EUR European Euro
# 5                         3.0      Ukraine  USD United States dollar
# ...                       ...          ...                       ...
# 49119                     NaN          NaN                       NaN
# 49120                     NaN          NaN                       NaN
# 49121                     NaN          NaN                       NaN
# 49122                     2.0       France         EUR European Euro
# 49123                     NaN        Italy         EUR European Euro
#
#             CompTotal LanguageChoice  \
# ResponseId
# 1             52800.0            Yes
# 2             90000.0            Yes
# 3           2214000.0            Yes
# 4             31200.0            Yes
# 5             60000.0            Yes
# ...               ...            ...
# 49119             NaN            NaN
# 49120             NaN            NaN
# 49121             NaN            NaN
# 49122         50000.0            Yes
# 49123         40000.0            NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                            Bash/Shell (all shells);Dart;SQL
# 2                                                        Java
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                             Java;Kotlin;SQL
# 5           C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                  C#;SQL
# 49123                                                     NaN
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                        Dart
# 2                                           Java;Python;Swift
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                                 Java;Kotlin
# 5                    C#;Java;JavaScript;Python;SQL;TypeScript
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;...
# 49123                                                     NaN
#
#                                      LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 1                                               Dart                NaN
# 2                                               Java                NaN
# 3                Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 4                                        Java;Kotlin                NaN
# 5           C#;Java;JavaScript;Python;SQL;TypeScript                NaN
# ...                                              ...                ...
# 49119                                            NaN                NaN
# 49120                                            NaN                NaN
# 49121                                            NaN                NaN
# 49122                                         C#;SQL      Visual FoxPro
# 49123                                            NaN                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 1                         NaN            Yes
# 2                         NaN            Yes
# 3                         NaN            Yes
# 4                         NaN             No
# 5                         NaN            Yes
# ...                       ...            ...
# 49119                     NaN            NaN
# 49120                     NaN            NaN
# 49121                     NaN            NaN
# 49122                     NaN            Yes
# 49123                     NaN            NaN
#
#                                        DatabaseHaveWorkedWith  ...  \
# ResponseId                                                     ...
# 1                                  Cloud Firestore;PostgreSQL  ...
# 2                                            Dynamodb;MongoDB  ...
# 3                                    MongoDB;MySQL;PostgreSQL  ...
# 4                                                         NaN  ...
# 5           Elasticsearch;Microsoft SQL Server;MySQL;Oracl...  ...
# ...                                                       ...  ...
# 49119                                                     NaN  ...
# 49120                                                     NaN  ...
# 49121                                                     NaN  ...
# 49122                              Microsoft SQL Server;MySQL  ...
# 49123                                                     NaN  ...
#
#              OfficeStackAsyncAdmired OfficeStackHaveEntry  \
# ResponseId
# 1                      Markdown File                  NaN
# 2             Confluence;GitHub;Jira                  NaN
# 3                 GitHub;GitLab;Jira                  NaN
# 4                        GitLab;Jira                  NaN
# 5           Azure Devops;GitHub;Jira                  NaN
# ...                              ...                  ...
# 49119                            NaN                  NaN
# 49120                            NaN                  NaN
# 49121                            NaN                  NaN
# 49122          Asana;GitHub;Obsidian                  NaN
# 49123                            NaN                  NaN
#
#            OfficeStackWantEntry  \
# ResponseId
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 49119                       NaN
# 49120                       NaN
# 49121                       NaN
# 49122                       NaN
# 49123                       NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 1           Stack Overflow;Reddit;GitHub (public projects,...
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4           Stack Overflow;Reddit;GitHub (public projects,...
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                           CommPlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 1                           NaN                  NaN            Yes
# 2                           NaN                  NaN            Yes
# 3                           NaN                  NaN            Yes
# 4                           NaN                  NaN             No
# 5                           NaN                  NaN            Yes
# ...                         ...                  ...            ...
# 49119                       NaN                  NaN            NaN
# 49120                       NaN                  NaN            NaN
# 49121                       NaN                  NaN            NaN
# 49122                       NaN                  NaN             No
# 49123                       NaN                  NaN            NaN
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 1           openAI GPT (chatbot models);openAI Image gener...
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);Gemini (...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                               AIModelsAdmired  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            AIModelsHaveEntry AIModelsWantEntry                SOAccount  \
# ResponseId
# 1                        NaN               NaN                      Yes
# 2                        NaN               NaN  Not sure/can't remember
# 3                        NaN               NaN  Not sure/can't remember
# 4                        NaN               NaN                      Yes
# 5                        NaN               NaN                       No
# ...                      ...               ...                      ...
# 49119                    NaN               NaN                      NaN
# 49120                    NaN               NaN                      NaN
# 49121                    NaN               NaN                      NaN
# 49122                    NaN               NaN                      NaN
# 49123                    NaN               NaN                      NaN
#
#                                 SOVisitFreq               SODuration  \
# ResponseId
# 1                      A few times per week   Between 5 and 10 years
# 2                    Multiple times per day  Between 10 and 15 years
# 3                      A few times per week   Between 5 and 10 years
# 4           A few times per month or weekly    Between 3 and 5 years
# 5           A few times per month or weekly   Between 5 and 10 years
# ...                                     ...                      ...
# 49119                                   NaN                      NaN
# 49120                                   NaN                      NaN
# 49121                                   NaN                      NaN
# 49122                                   NaN                      NaN
# 49123                                   NaN                      NaN
#
#                                                    SOPartFreq  \
# ResponseId
# 1           I have never participated in Q&A on Stack Over...
# 2                       Infrequently, less than once per year
# 3                       Infrequently, less than once per year
# 4           I have never participated in Q&A on Stack Over...
# 5                       Infrequently, less than once per year
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                SO_Dev_Content SO_Actions_1  \
# ResponseId
# 1                                                         NaN          1.0
# 2           Chat (people);Message Boards;Long-form article...          6.0
# 3           Chat (people);Videos;Lists of recommendations ...          3.0
# 4                                        Videos;Chat (bot/AI)          1.0
# 5                                          Long-form articles          1.0
# ...                                                       ...          ...
# 49119                                                     NaN          NaN
# 49120                                                     NaN          NaN
# 49121                                                     NaN          NaN
# 49122                                                     NaN          NaN
# 49123                                                     NaN          NaN
#
#            SO_Actions_16 SO_Actions_3 SO_Actions_4 SO_Actions_5 SO_Actions_6  \
# ResponseId
# 1                    NaN          6.0          2.0          3.0          7.0
# 2                    NaN          5.0          8.0          2.0          4.0
# 3                    NaN          4.0          5.0          1.0          2.0
# 4                    NaN          4.0          5.0          6.0          7.0
# 5                    NaN          7.0          4.0          2.0          5.0
# ...                  ...          ...          ...          ...          ...
# 49119                NaN          NaN          NaN          NaN          NaN
# 49120                NaN          NaN          NaN          NaN          NaN
# 49121                NaN          NaN          NaN          NaN          NaN
# 49122                NaN          NaN          NaN          NaN          NaN
# 49123                NaN          NaN          NaN          NaN          NaN
#
#            SO_Actions_9 SO_Actions_7 SO_Actions_10 SO_Actions_15  \
# ResponseId
# 1                   8.0          9.0          11.0          15.0
# 2                   9.0         10.0          11.0          15.0
# 3                   7.0          9.0          11.0          15.0
# 4                   8.0          9.0          11.0          15.0
# 5                  10.0          6.0          12.0          15.0
# ...                 ...          ...           ...           ...
# 49119               NaN          NaN           NaN           NaN
# 49120               NaN          NaN           NaN           NaN
# 49121               NaN          NaN           NaN           NaN
# 49122               NaN          NaN           NaN           NaN
# 49123               NaN          NaN           NaN           NaN
#
#            SO_Actions_15_TEXT          SOComm              SOFriction  \
# ResponseId
# 1                         NaN         Neutral    Rarely, almost never
# 2                         NaN   Yes, somewhat  About half of the time
# 3                         NaN         Neutral  About half of the time
# 4                         NaN         Neutral    Rarely, almost never
# 5                         NaN  No, not really    Rarely, almost never
# ...                       ...             ...                     ...
# 49119                     NaN             NaN                     NaN
# 49120                     NaN             NaN                     NaN
# 49121                     NaN             NaN                     NaN
# 49122                     NaN             NaN                     NaN
# 49123                     NaN             NaN                     NaN
#
#                                                AISelect       AISent  \
# ResponseId
# 1           Yes, I use AI tools monthly or infrequently  Indifferent
# 2                            Yes, I use AI tools weekly  Indifferent
# 3                             Yes, I use AI tools daily    Favorable
# 4                            Yes, I use AI tools weekly    Favorable
# 5                            Yes, I use AI tools weekly    Favorable
# ...                                                 ...          ...
# 49119                                               NaN          NaN
# 49120                                               NaN          NaN
# 49121                                               NaN          NaN
# 49122                         Yes, I use AI tools daily    Favorable
# 49123                                               NaN          NaN
#
#                                  AIAcc  \
# ResponseId
# 1           Neither trust nor distrust
# 2           Neither trust nor distrust
# 3                       Somewhat trust
# 4                       Somewhat trust
# 5           Neither trust nor distrust
# ...                                ...
# 49119                              NaN
# 49120                              NaN
# 49121                              NaN
# 49122                Somewhat distrust
# 49123                              NaN
#
#                                                 AIComplex  \
# ResponseId
# 1                           Bad at handling complex tasks
# 2                           Bad at handling complex tasks
# 3           Neither good or bad at handling complex tasks
# 4                           Bad at handling complex tasks
# 5           Good, but not great at handling complex tasks
# ...                                                   ...
# 49119                                                 NaN
# 49120                                                 NaN
# 49121                                                 NaN
# 49122                       Bad at handling complex tasks
# 49123                                                 NaN
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 1           Learning about a codebase;Writing code;Search ...
# 2                       Learning new concepts or technologies
# 3           Documenting code;Debugging or fixing code;Test...
# 4                                                         NaN
# 5           Learning about a codebase;Writing code;Debuggi...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Writing code;Documenting code;Generating conte...
# 49123                                                     NaN
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 1           Project planning;Deployment and monitoring;Lea...
# 2           Learning about a codebase;Project planning;Com...
# 3                                                         NaN
# 4           Project planning;Documenting code;Testing code...
# 5           Project planning;Documenting code;Testing code...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Debugging or fixing code;Testing code;Committi...
# 49123                                                     NaN
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 1           Documenting code;Debugging or fixing code;Test...
# 2           Writing code;Documenting code;Debugging or fix...
# 3           Project planning;Committing and reviewing code...
# 4           Learning about a codebase;Writing code;Debuggi...
# 5                        Generating content or synthetic data
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                        Project planning
# 49123                                                     NaN
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Learning about a codebase;Writing code;Generat...
# 4           Search for answers;Generating content or synth...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                     AIToolCurrently mostly AI  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Learning about a codebase;Search for answers;L...
# 49123                                                     NaN
#
#                                                 AIFrustration  \
# ResponseId
# 1           AI solutions that are almost right, but not quite
# 2           AI solutions that are almost right, but not qu...
# 3           AI solutions that are almost right, but not qu...
# 4           AI solutions that are almost right, but not qu...
# 5           AI solutions that are almost right, but not quite
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# ...
#
#                                                     AIExplain  \
# ResponseId
# 1                                                          No
# 2                                                          No
# 3                                                          No
# 4                                                          NO
# 5                                                      partly
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       no, IA do not control de code part, it's essen...
# 49123                                                     NaN
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       No, I use AI exclusively in copilot/autocomple...
# 49123                                                     NaN
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
# ...                             ...                   ...
# 49119                           NaN                   NaN
# 49120                           NaN                   NaN
# 49121                           NaN                   NaN
# 49122       Not at all or minimally             Marketing
# 49123                           NaN                   NaN
#
#                                              AgentUsesGeneral  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                            Multi-platform search enablement
# 4                                         Language processing
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Multi-platform search enablement;Language proc...
# 49123                                                     NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#             AIAgentImpactStrongly agree  AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# 5                                   NaN                             NaN
# ...                                 ...                             ...
# 49119                               NaN                             NaN
# 49120                               NaN                             NaN
# 49121                               NaN                             NaN
# 49122                               NaN                             NaN
# 49123                               NaN                             NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#             AIAgentChallengesStrongly disagree  AIAgentKnowledge  \
# ResponseId
# 1                                          NaN               NaN
# 2                                          NaN               NaN
# 3                                          NaN             Redis
# 4                                          NaN               NaN
# 5                                          NaN               NaN
# ...                                        ...               ...
# 49119                                      NaN               NaN
# 49120                                      NaN               NaN
# 49121                                      NaN               NaN
# 49122                                      NaN               NaN
# 49123                                      NaN               NaN
#
#             AIAgentKnowWrite  AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                        NaN             Vertex AI              NaN
# 2                        NaN                   NaN              NaN
# 3                        NaN                   NaN              NaN
# 4                        NaN                   NaN              NaN
# 5                        NaN                   NaN              NaN
# ...                      ...                   ...              ...
# 49119                    NaN                   NaN              NaN
# 49120                    NaN                   NaN              NaN
# 49121                    NaN                   NaN              NaN
# 49122                    NaN                   NaN              NaN
# 49123                    NaN                   NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# 5                           NaN             NaN
# ...                         ...             ...
# 49119                       NaN             NaN
# 49120                       NaN             NaN
# 49121                       NaN             NaN
# 49122                       NaN             NaN
# 49123                       NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
# ...                                                      ...             ...
# 49119                                                    NaN             NaN
# 49120                                                    NaN             NaN
# 49121                                                    NaN             NaN
# 49122                                                    NaN             NaN
# 49123                                                    NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            ConvertedCompYearly JobSat
# ResponseId
# 1                      61256.0   10.0
# 2                     104413.0    9.0
# 3                      53061.0    8.0
# 4                      36197.0    6.0
# 5                      60000.0    7.0
# ...                        ...    ...
# 49119                      NaN    8.0
# 49120                      NaN    NaN
# 49121                      NaN    NaN
# 49122                      NaN    7.0
# 49123                      NaN    8.0
#
# [49123 rows x 169 columns]

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 1     14.0
# 2     10.0
# 3     12.0
# 4      5.0
# 5     22.0
# 6     20.0
# 7     13.0
# 8     30.0
# 9     15.0
# 10    10.0
# Name: YearsCode, dtype: float64

# %%
df["YearsCode"].mean()
# Out:
# np.float64(16.57525581395349)

# %%
df["YearsCode"].astype(float)
# Out:
# ResponseId
# 1        14.0
# 2        10.0
# 3        12.0
# 4         5.0
# 5        22.0
#          ...
# 49119    13.0
# 49120    15.0
# 49121     NaN
# 49122    14.0
# 49123    15.0
# Name: YearsCode, Length: 49123, dtype: float64

# %%
# view unique value of a series
df["YearsCode"].unique()
# Out:
# array([ 14.,  10.,  12.,   5.,  22.,  20.,  13.,  30.,  15.,   9.,   6.,
#         nan,   3.,  40.,   8.,  45.,  35.,  11.,   7.,  47.,  41.,  36.,
#         23.,  29.,  26.,  25.,  38.,  21.,  19.,  18.,  16.,   4.,  17.,
#         42.,  27.,  24.,   2.,  28.,  37.,  32.,   1.,  39.,  53.,  33.,
#         50.,  48.,  44.,  31.,  46.,  43.,  49.,  52.,  34.,  51.,  58.,
#         57.,  54.,  63.,  60.,  55.,  65., 100.,  99.,  56.,  69.,  90.,
#         61.,  67.,  75.,  64.,  98.,  68.,  89.,  62.,  78.,  70.,  76.,
#         82.,  59.])

# %%
df["YearsCode"].median()
# Out:
# np.float64(14.0)
